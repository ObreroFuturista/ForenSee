# %% [markdown]
# <a href="https://colab.research.google.com/github/ObreroFuturista/ForenSee/blob/main/ForenSee_entrenamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Descargar yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16000, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 16000 (delta 20), reused 20 (delta 12), pack-reused 15967
# Receiving objects: 100% (16000/16000), 14.59 MiB | 6.69 MiB/s, done.
# Resolving deltas: 100% (10986/10986), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.6/615.6 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.3 MB/s eta 0:00:00
# ...

# %%
# !unzip /content/drive/MyDrive/Experimental/base.zip  -d /content/
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#   inflating: /content/base_r1_data/train/images/Euphoria_26486298_research.jpg
#   inflating: /content/base_r1_data/train/images/Lucilia_70481201.jpg
#   inflating: /content/base_r1_data/train/images/Oxelytrum_234472664_research.jpg
#   inflating: /content/base_r1_data/train/images/Euphoria_242359557_research.jpg
#   inflating: /content/base_r1_data/train/images/Eleodes_157978109_research.jpg
#   inflating: /content/base_r1_data/train/images/Sarcophagidae_1806644.jpg
#   inflating: /content/base_r1_data/train/images/Sarcophagidae_98105127.jpg
#   inflating: /content/base_r1_data/train/images/Incisitermes_163899795.jpg
#   inflating: /content/base_r1_data/train/images/Nicrophorus_25143701.jpg
#   inflating: /content/base_r1_data/train/images/Muscidae_23719165.jpg
#   inflating: /content/base_r1_data/train/images/Hydnocerinae_150394320.jpg
#   inflating: /content/base_r1_data/train/images/Enoclerus_59986013.jpg
# ...

# %%
data_yaml = '''
train: /content/base_r1_data/train/images
val: /content/base_r1_data/val/images

nc: 13  # Número de clases
names: [
  'Blattidae',
  'Calliphoridae',
  'Cleridae',
  'Dermaptera',
  'Dermestidae',
  'Histeridae',
  'Isoptera',
  'Muscidae',
  'Sarcophagidae',
  'Scarabaeidae',
  'Shilphidae',
  'Staphylinidae',
  'Tenebrionidae'
]
'''

with open("data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# !python train.py --img 640 --batch 192 --epochs 100 --data data.yaml --cfg models/yolov5s.yaml --weights yolov5s.pt --name forensee_base200
# Out:
# train: weights=yolov5s.pt, cfg=models/yolov5s.yaml, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=192, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=forensee_base200, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-225-gbb9706e Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
#
# ...

# %%
# !zip -r /content/drive/MyDrive/Experimental/insectmodel_base200.zip /content/yolov5/runs/train/
# Out:
#   adding: content/yolov5/runs/train/ (stored 0%)
#   adding: content/yolov5/runs/train/forensee_base200/ (stored 0%)
#   adding: content/yolov5/runs/train/forensee_base200/val_batch0_labels.jpg (deflated 14%)
#   adding: content/yolov5/runs/train/forensee_base200/opt.yaml (deflated 50%)
#   adding: content/yolov5/runs/train/forensee_base200/R_curve.png (deflated 5%)
#   adding: content/yolov5/runs/train/forensee_base200/val_batch1_pred.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/forensee_base200/results.png (deflated 8%)
#   adding: content/yolov5/runs/train/forensee_base200/val_batch1_labels.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/forensee_base200/train_batch2.jpg (deflated 4%)
#   adding: content/yolov5/runs/train/forensee_base200/val_batch2_pred.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/forensee_base200/labels_correlogram.jpg (deflated 37%)
#   adding: content/yolov5/runs/train/forensee_base200/train_batch1.jpg (deflated 4%)
# ...
